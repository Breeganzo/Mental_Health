# %%
import numpy as np
import pandas as pd
# Out:
# /kaggle/input/playground-series-s4e11/sample_submission.csv
# /kaggle/input/playground-series-s4e11/train.csv
# /kaggle/input/playground-series-s4e11/test.csv

# %%
train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")

# %%
test
# Out:
#            id     Name  Gender   Age           City  \
# 0      140700   Shivam    Male  53.0  Visakhapatnam
# 1      140701    Sanya  Female  58.0        Kolkata
# 2      140702     Yash    Male  53.0         Jaipur
# 3      140703   Nalini  Female  23.0         Rajkot
# 4      140704  Shaurya    Male  47.0         Kalyan
# ...       ...      ...     ...   ...            ...
# 93795  234495     Zoya  Female  49.0         Jaipur
# 93796  234496    Shlok    Male  29.0      Ahmedabad
# 93797  234497    Rishi    Male  24.0  Visakhapatnam
# 93798  234498   Eshita  Female  23.0         Kalyan
# 93799  234499    Gauri  Female  43.0       Varanasi
#
#       Working Professional or Student              Profession  \
# 0                Working Professional                   Judge
# 1                Working Professional  Educational Consultant
# 2                Working Professional                 Teacher
# 3                             Student                     NaN
# ...

# %%
train
# Out:
#             id      Name  Gender   Age           City  \
# 0            0  Aaradhya  Female  49.0       Ludhiana
# 1            1     Vivan    Male  26.0       Varanasi
# 2            2    Yuvraj    Male  33.0  Visakhapatnam
# 3            3    Yuvraj    Male  22.0         Mumbai
# 4            4      Rhea  Female  30.0         Kanpur
# ...        ...       ...     ...   ...            ...
# 140695  140695     Vidya  Female  18.0      Ahmedabad
# 140696  140696      Lata  Female  41.0      Hyderabad
# 140697  140697   Aanchal  Female  24.0        Kolkata
# 140698  140698    Prachi  Female  49.0       Srinagar
# 140699  140699       Sai    Male  27.0          Patna
#
#        Working Professional or Student         Profession  Academic Pressure  \
# 0                 Working Professional               Chef                NaN
# 1                 Working Professional            Teacher                NaN
# 2                              Student                NaN                5.0
# ...

# %%
train.isnull().sum()
# Out:
# id                                            0
# Name                                          0
# Gender                                        0
# Age                                           0
# City                                          0
# Working Professional or Student               0
# Profession                                36630
# Academic Pressure                        112803
# Work Pressure                             27918
# CGPA                                     112802
# Study Satisfaction                       112803
# Job Satisfaction                          27910
# Sleep Duration                                0
# Dietary Habits                                4
# Degree                                        2
# Have you ever had suicidal thoughts ?         0
# Work/Study Hours                              0
# Financial Stress                              4
# Family History of Mental Illness              0
# Depression                                    0
# ...

# %%
train.describe()
# Out:
#                   id            Age  Academic Pressure  Work Pressure  \
# count  140700.000000  140700.000000       27897.000000  112782.000000
# mean    70349.500000      40.388621           3.142273       2.998998
# std     40616.735775      12.384099           1.380457       1.405771
# min         0.000000      18.000000           1.000000       1.000000
# 25%     35174.750000      29.000000           2.000000       2.000000
# 50%     70349.500000      42.000000           3.000000       3.000000
# 75%    105524.250000      51.000000           4.000000       4.000000
# max    140699.000000      60.000000           5.000000       5.000000
#
#                CGPA  Study Satisfaction  Job Satisfaction  Work/Study Hours  \
# count  27898.000000        27897.000000     112790.000000     140700.000000
# mean       7.658636            2.944940          2.974404          6.252679
# std        1.464466            1.360197          1.416078          3.853615
# ...

# %%
train_dup = train.copy()
test_dup = test.copy()

# %%
train_dup['Satisfaction'] = train_dup[['Study Satisfaction','Job Satisfaction']].mean(axis=1)
train_dup
# Out:
#             id      Name  Gender   Age           City  \
# 0            0  Aaradhya  Female  49.0       Ludhiana
# 1            1     Vivan    Male  26.0       Varanasi
# 2            2    Yuvraj    Male  33.0  Visakhapatnam
# 3            3    Yuvraj    Male  22.0         Mumbai
# 4            4      Rhea  Female  30.0         Kanpur
# ...        ...       ...     ...   ...            ...
# 140695  140695     Vidya  Female  18.0      Ahmedabad
# 140696  140696      Lata  Female  41.0      Hyderabad
# 140697  140697   Aanchal  Female  24.0        Kolkata
# 140698  140698    Prachi  Female  49.0       Srinagar
# 140699  140699       Sai    Male  27.0          Patna
#
#        Working Professional or Student         Profession  Academic Pressure  \
# 0                 Working Professional               Chef                NaN
# 1                 Working Professional            Teacher                NaN
# 2                              Student                NaN                5.0
# ...

# %%
test_dup['Satisfaction'] = test_dup[['Study Satisfaction','Job Satisfaction']].mean(axis=1)
test_dup
# Out:
#            id     Name  Gender   Age           City  \
# 0      140700   Shivam    Male  53.0  Visakhapatnam
# 1      140701    Sanya  Female  58.0        Kolkata
# 2      140702     Yash    Male  53.0         Jaipur
# 3      140703   Nalini  Female  23.0         Rajkot
# 4      140704  Shaurya    Male  47.0         Kalyan
# ...       ...      ...     ...   ...            ...
# 93795  234495     Zoya  Female  49.0         Jaipur
# 93796  234496    Shlok    Male  29.0      Ahmedabad
# 93797  234497    Rishi    Male  24.0  Visakhapatnam
# 93798  234498   Eshita  Female  23.0         Kalyan
# 93799  234499    Gauri  Female  43.0       Varanasi
#
#       Working Professional or Student              Profession  \
# 0                Working Professional                   Judge
# 1                Working Professional  Educational Consultant
# 2                Working Professional                 Teacher
# 3                             Student                     NaN
# ...

# %%
train_dup = train_dup.drop(['Study Satisfaction','Job Satisfaction'],axis=1)
train_dup
# Out:
#             id      Name  Gender   Age           City  \
# 0            0  Aaradhya  Female  49.0       Ludhiana
# 1            1     Vivan    Male  26.0       Varanasi
# 2            2    Yuvraj    Male  33.0  Visakhapatnam
# 3            3    Yuvraj    Male  22.0         Mumbai
# 4            4      Rhea  Female  30.0         Kanpur
# ...        ...       ...     ...   ...            ...
# 140695  140695     Vidya  Female  18.0      Ahmedabad
# 140696  140696      Lata  Female  41.0      Hyderabad
# 140697  140697   Aanchal  Female  24.0        Kolkata
# 140698  140698    Prachi  Female  49.0       Srinagar
# 140699  140699       Sai    Male  27.0          Patna
#
#        Working Professional or Student         Profession  Academic Pressure  \
# 0                 Working Professional               Chef                NaN
# 1                 Working Professional            Teacher                NaN
# 2                              Student                NaN                5.0
# ...

# %%
test_dup = test_dup.drop(['Study Satisfaction','Job Satisfaction'],axis=1)
test_dup
# Out:
#            id     Name  Gender   Age           City  \
# 0      140700   Shivam    Male  53.0  Visakhapatnam
# 1      140701    Sanya  Female  58.0        Kolkata
# 2      140702     Yash    Male  53.0         Jaipur
# 3      140703   Nalini  Female  23.0         Rajkot
# 4      140704  Shaurya    Male  47.0         Kalyan
# ...       ...      ...     ...   ...            ...
# 93795  234495     Zoya  Female  49.0         Jaipur
# 93796  234496    Shlok    Male  29.0      Ahmedabad
# 93797  234497    Rishi    Male  24.0  Visakhapatnam
# 93798  234498   Eshita  Female  23.0         Kalyan
# 93799  234499    Gauri  Female  43.0       Varanasi
#
#       Working Professional or Student              Profession  \
# 0                Working Professional                   Judge
# 1                Working Professional  Educational Consultant
# 2                Working Professional                 Teacher
# 3                             Student                     NaN
# ...

# %%
train_dup['Profession'].unique()
# Out:
# array(['Chef', 'Teacher', nan, 'Business Analyst', 'Finanancial Analyst',
#        'Chemist', 'Electrician', 'Software Engineer', 'Data Scientist',
#        'Plumber', 'Marketing Manager', 'Accountant', 'Entrepreneur',
#        'HR Manager', 'UX/UI Designer', 'Content Writer',
#        'Educational Consultant', 'Civil Engineer', 'Manager',
#        'Pharmacist', 'Financial Analyst', 'Architect',
#        'Mechanical Engineer', 'Customer Support', 'Consultant', 'Judge',
#        'Researcher', 'Pilot', 'Graphic Designer', 'Travel Consultant',
#        'Digital Marketer', 'Lawyer', 'Research Analyst',
#        'Sales Executive', 'Doctor', 'Unemployed', 'Investment Banker',
#        'Family Consultant', 'B.Com', 'BE', 'Student', 'Yogesh', 'Dev',
#        'MBA', 'LLM', 'BCA', 'Academic', 'Profession', 'FamilyVirar',
#        'City Manager', 'BBA', 'Medical Doctor', 'Working Professional',
#        'MBBS', 'Patna', 'Unveil', 'B.Ed', 'Nagpur', 'Moderate', 'M.Ed',
# ...

# %%
# Identify valid professions with counts greater than 10
valid_professions = train_dup["Profession"].value_counts()[train_dup["Profession"].value_counts() > 10].index

# Replace professions with counts <= 10 with "Others"
train_dup["Profession"] = train_dup["Profession"].apply(lambda x: x if x in valid_professions else "Others")

# %%
# Identify valid professions with counts greater than 10
valid_professions = test_dup["Profession"].value_counts()[test_dup["Profession"].value_counts() > 10].index

# Replace professions with counts <= 10 with "Others"
test_dup["Profession"] = test_dup["Profession"].apply(lambda x: x if x in valid_professions else "Others")

# %%
train_dup['Profession'].unique()
# Out:
# array(['Chef', 'Teacher', 'Others', 'Business Analyst',
#        'Finanancial Analyst', 'Chemist', 'Electrician',
#        'Software Engineer', 'Data Scientist', 'Plumber',
#        'Marketing Manager', 'Accountant', 'Entrepreneur', 'HR Manager',
#        'UX/UI Designer', 'Content Writer', 'Educational Consultant',
#        'Civil Engineer', 'Manager', 'Pharmacist', 'Financial Analyst',
#        'Architect', 'Mechanical Engineer', 'Customer Support',
#        'Consultant', 'Judge', 'Researcher', 'Pilot', 'Graphic Designer',
#        'Travel Consultant', 'Digital Marketer', 'Lawyer',
#        'Research Analyst', 'Sales Executive', 'Doctor',
#        'Investment Banker'], dtype=object)

# %%
train_dup['Profession'].unique()
# Out:
# array(['Chef', 'Teacher', 'Others', 'Business Analyst',
#        'Finanancial Analyst', 'Chemist', 'Electrician',
#        'Software Engineer', 'Data Scientist', 'Plumber',
#        'Marketing Manager', 'Accountant', 'Entrepreneur', 'HR Manager',
#        'UX/UI Designer', 'Content Writer', 'Educational Consultant',
#        'Civil Engineer', 'Manager', 'Pharmacist', 'Financial Analyst',
#        'Architect', 'Mechanical Engineer', 'Customer Support',
#        'Consultant', 'Judge', 'Researcher', 'Pilot', 'Graphic Designer',
#        'Travel Consultant', 'Digital Marketer', 'Lawyer',
#        'Research Analyst', 'Sales Executive', 'Doctor',
#        'Investment Banker'], dtype=object)

# %%
train_dup
# Out:
#             id      Name  Gender   Age           City  \
# 0            0  Aaradhya  Female  49.0       Ludhiana
# 1            1     Vivan    Male  26.0       Varanasi
# 2            2    Yuvraj    Male  33.0  Visakhapatnam
# 3            3    Yuvraj    Male  22.0         Mumbai
# 4            4      Rhea  Female  30.0         Kanpur
# ...        ...       ...     ...   ...            ...
# 140695  140695     Vidya  Female  18.0      Ahmedabad
# 140696  140696      Lata  Female  41.0      Hyderabad
# 140697  140697   Aanchal  Female  24.0        Kolkata
# 140698  140698    Prachi  Female  49.0       Srinagar
# 140699  140699       Sai    Male  27.0          Patna
#
#        Working Professional or Student         Profession  Academic Pressure  \
# 0                 Working Professional               Chef                NaN
# 1                 Working Professional            Teacher                NaN
# 2                              Student             Others                5.0
# ...

# %%
test_dup
# Out:
#            id     Name  Gender   Age           City  \
# 0      140700   Shivam    Male  53.0  Visakhapatnam
# 1      140701    Sanya  Female  58.0        Kolkata
# 2      140702     Yash    Male  53.0         Jaipur
# 3      140703   Nalini  Female  23.0         Rajkot
# 4      140704  Shaurya    Male  47.0         Kalyan
# ...       ...      ...     ...   ...            ...
# 93795  234495     Zoya  Female  49.0         Jaipur
# 93796  234496    Shlok    Male  29.0      Ahmedabad
# 93797  234497    Rishi    Male  24.0  Visakhapatnam
# 93798  234498   Eshita  Female  23.0         Kalyan
# 93799  234499    Gauri  Female  43.0       Varanasi
#
#       Working Professional or Student              Profession  \
# 0                Working Professional                   Judge
# 1                Working Professional  Educational Consultant
# 2                Working Professional                 Teacher
# 3                             Student                  Others
# ...

# %%
train_dup.describe()
# Out:
#                   id            Age  Academic Pressure  Work Pressure  \
# count  140700.000000  140700.000000       27897.000000  112782.000000
# mean    70349.500000      40.388621           3.142273       2.998998
# std     40616.735775      12.384099           1.380457       1.405771
# min         0.000000      18.000000           1.000000       1.000000
# 25%     35174.750000      29.000000           2.000000       2.000000
# 50%     70349.500000      42.000000           3.000000       3.000000
# 75%    105524.250000      51.000000           4.000000       4.000000
# max    140699.000000      60.000000           5.000000       5.000000
#
#                CGPA  Work/Study Hours  Financial Stress     Depression  \
# count  27898.000000     140700.000000     140696.000000  140700.000000
# mean       7.658636          6.252679          2.988983       0.181713
# std        1.464466          3.853615          1.413633       0.385609
# ...

# %%
train_dup['Pressure'] = train_dup[['Academic Pressure','Work Pressure']].mean(axis=1)
train_dup
# Out:
#             id      Name  Gender   Age           City  \
# 0            0  Aaradhya  Female  49.0       Ludhiana
# 1            1     Vivan    Male  26.0       Varanasi
# 2            2    Yuvraj    Male  33.0  Visakhapatnam
# 3            3    Yuvraj    Male  22.0         Mumbai
# 4            4      Rhea  Female  30.0         Kanpur
# ...        ...       ...     ...   ...            ...
# 140695  140695     Vidya  Female  18.0      Ahmedabad
# 140696  140696      Lata  Female  41.0      Hyderabad
# 140697  140697   Aanchal  Female  24.0        Kolkata
# 140698  140698    Prachi  Female  49.0       Srinagar
# 140699  140699       Sai    Male  27.0          Patna
#
#        Working Professional or Student         Profession  Academic Pressure  \
# 0                 Working Professional               Chef                NaN
# 1                 Working Professional            Teacher                NaN
# 2                              Student             Others                5.0
# ...

# %%
test_dup['Pressure'] = test_dup[['Academic Pressure','Work Pressure']].mean(axis=1)
test_dup
# Out:
#            id     Name  Gender   Age           City  \
# 0      140700   Shivam    Male  53.0  Visakhapatnam
# 1      140701    Sanya  Female  58.0        Kolkata
# 2      140702     Yash    Male  53.0         Jaipur
# 3      140703   Nalini  Female  23.0         Rajkot
# 4      140704  Shaurya    Male  47.0         Kalyan
# ...       ...      ...     ...   ...            ...
# 93795  234495     Zoya  Female  49.0         Jaipur
# 93796  234496    Shlok    Male  29.0      Ahmedabad
# 93797  234497    Rishi    Male  24.0  Visakhapatnam
# 93798  234498   Eshita  Female  23.0         Kalyan
# 93799  234499    Gauri  Female  43.0       Varanasi
#
#       Working Professional or Student              Profession  \
# 0                Working Professional                   Judge
# 1                Working Professional  Educational Consultant
# 2                Working Professional                 Teacher
# 3                             Student                  Others
# ...

# %%
train_dup = train_dup.drop(['Academic Pressure','Work Pressure'],axis=1)
train_dup
# Out:
#             id      Name  Gender   Age           City  \
# 0            0  Aaradhya  Female  49.0       Ludhiana
# 1            1     Vivan    Male  26.0       Varanasi
# 2            2    Yuvraj    Male  33.0  Visakhapatnam
# 3            3    Yuvraj    Male  22.0         Mumbai
# 4            4      Rhea  Female  30.0         Kanpur
# ...        ...       ...     ...   ...            ...
# 140695  140695     Vidya  Female  18.0      Ahmedabad
# 140696  140696      Lata  Female  41.0      Hyderabad
# 140697  140697   Aanchal  Female  24.0        Kolkata
# 140698  140698    Prachi  Female  49.0       Srinagar
# 140699  140699       Sai    Male  27.0          Patna
#
#        Working Professional or Student         Profession  CGPA  \
# 0                 Working Professional               Chef   NaN
# 1                 Working Professional            Teacher   NaN
# 2                              Student             Others  8.97
# ...

# %%
test_dup = test_dup.drop(['Academic Pressure','Work Pressure'],axis=1)
test_dup
# Out:
#            id     Name  Gender   Age           City  \
# 0      140700   Shivam    Male  53.0  Visakhapatnam
# 1      140701    Sanya  Female  58.0        Kolkata
# 2      140702     Yash    Male  53.0         Jaipur
# 3      140703   Nalini  Female  23.0         Rajkot
# 4      140704  Shaurya    Male  47.0         Kalyan
# ...       ...      ...     ...   ...            ...
# 93795  234495     Zoya  Female  49.0         Jaipur
# 93796  234496    Shlok    Male  29.0      Ahmedabad
# 93797  234497    Rishi    Male  24.0  Visakhapatnam
# 93798  234498   Eshita  Female  23.0         Kalyan
# 93799  234499    Gauri  Female  43.0       Varanasi
#
#       Working Professional or Student              Profession  CGPA  \
# 0                Working Professional                   Judge   NaN
# 1                Working Professional  Educational Consultant   NaN
# 2                Working Professional                 Teacher   NaN
# ...

# %%
target_col = 'Depression'

# Move the target column to the end
cols = [col for col in train_dup.columns if col != target_col] + [target_col]
train_dup = train_dup[cols]
train_dup
# Out:
#             id      Name  Gender   Age           City  \
# 0            0  Aaradhya  Female  49.0       Ludhiana
# 1            1     Vivan    Male  26.0       Varanasi
# 2            2    Yuvraj    Male  33.0  Visakhapatnam
# 3            3    Yuvraj    Male  22.0         Mumbai
# 4            4      Rhea  Female  30.0         Kanpur
# ...        ...       ...     ...   ...            ...
# 140695  140695     Vidya  Female  18.0      Ahmedabad
# 140696  140696      Lata  Female  41.0      Hyderabad
# 140697  140697   Aanchal  Female  24.0        Kolkata
# 140698  140698    Prachi  Female  49.0       Srinagar
# 140699  140699       Sai    Male  27.0          Patna
#
#        Working Professional or Student         Profession  CGPA  \
# 0                 Working Professional               Chef   NaN
# 1                 Working Professional            Teacher   NaN
# 2                              Student             Others  8.97
# ...

# %%
train_dup.isnull().sum()
# Out:
# id                                            0
# Name                                          0
# Gender                                        0
# Age                                           0
# City                                          0
# Working Professional or Student               0
# Profession                                    0
# CGPA                                     112802
# Sleep Duration                                0
# Dietary Habits                                4
# Degree                                        2
# Have you ever had suicidal thoughts ?         0
# Work/Study Hours                              0
# Financial Stress                              4
# Family History of Mental Illness              0
# Satisfaction                                 15
# Pressure                                     21
# Depression                                    0
# dtype: int64

# %%
test_dup.isnull().sum()
# Out:
# id                                           0
# Name                                         0
# Gender                                       0
# Age                                          0
# City                                         0
# Working Professional or Student              0
# Profession                                   0
# CGPA                                     75034
# Sleep Duration                               0
# Dietary Habits                               5
# Degree                                       2
# Have you ever had suicidal thoughts ?        0
# Work/Study Hours                             0
# Financial Stress                             0
# Family History of Mental Illness             0
# Satisfaction                                 8
# Pressure                                    12
# dtype: int64

# %%
train_dup.describe()
# Out:
#                   id            Age          CGPA  Work/Study Hours  \
# count  140700.000000  140700.000000  27898.000000     140700.000000
# mean    70349.500000      40.388621      7.658636          6.252679
# std     40616.735775      12.384099      1.464466          3.853615
# min         0.000000      18.000000      5.030000          0.000000
# 25%     35174.750000      29.000000      6.290000          3.000000
# 50%     70349.500000      42.000000      7.770000          6.000000
# 75%    105524.250000      51.000000      8.920000         10.000000
# max    140699.000000      60.000000     10.000000         12.000000
#
#        Financial Stress   Satisfaction       Pressure     Depression
# count     140696.000000  140685.000000  140679.000000  140700.000000
# mean           2.988983       2.968557       3.027410       0.181713
# std            1.413633       1.405216       1.401947       0.385609
# min            1.000000       1.000000       1.000000       0.000000
# ...

# %%
import seaborn as sns
sns.pairplot(train_dup)
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
train_dup.columns
# Out:
# Index(['id', 'Name', 'Gender', 'Age', 'City',
#        'Working Professional or Student', 'Profession', 'CGPA',
#        'Sleep Duration', 'Dietary Habits', 'Degree',
#        'Have you ever had suicidal thoughts ?', 'Work/Study Hours',
#        'Financial Stress', 'Family History of Mental Illness', 'Satisfaction',
#        'Pressure', 'Depression'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder

# Initialize a label encoder
label_encoder = LabelEncoder()

# Copy the dataframe to avoid modifying the original
train_encoded = train_dup.copy()

# Encode categorical columns
categorical_columns = train_dup.select_dtypes(include=["object", "category"]).columns
for col in categorical_columns:
    train_encoded[col] = label_encoder.fit_transform(train_dup[col])

# Combine numerical and encoded categorical columns
all_columns = list(train_encoded.columns)

# Calculate correlations with "depression"
correlations = train_encoded[all_columns].corrwith(train_encoded["Depression"])
print(correlations)
# Out:
# id                                       0.003944
# Name                                    -0.028897
# Gender                                   0.008144
# Age                                     -0.564671
# City                                    -0.020915
# Working Professional or Student         -0.520790
# Profession                               0.137059
# CGPA                                     0.021729
# Sleep Duration                           0.014454
# Dietary Habits                           0.143445
# Degree                                  -0.045514
# Have you ever had suicidal thoughts ?    0.349066
# Work/Study Hours                         0.191746
# Financial Stress                         0.227237
# Family History of Mental Illness         0.016502
# Satisfaction                            -0.142350
# Pressure                                 0.263495
# Depression                               1.000000
# dtype: float64

# %%
train_encoded
# Out:
#             id  Name  Gender   Age  City  Working Professional or Student  \
# 0            0    11       0  49.0    50                                1
# 1            1   407       1  26.0    93                                1
# 2            2   417       1  33.0    97                                0
# 3            3   417       1  22.0    64                                1
# 4            4   286       0  30.0    37                                1
# ...        ...   ...     ...   ...   ...                              ...
# 140695  140695   398       0  18.0     4                                1
# 140696  140696   193       0  41.0    26                                1
# 140697  140697     7       0  24.0    44                                1
# 140698  140698   252       0  49.0    84                                1
# 140699  140699   318       1  27.0    72                                0
#
#         Profession  CGPA  Sleep Duration  Dietary Habits  Degree  \
# ...

# %%
import matplotlib.pyplot as plt
corr_matrix = train_encoded.corr()
plt.figure(figsize=(20,8))
sns.heatmap(corr_matrix,annot=True,cmap='coolwarm',linewidths=0.5)
# Out:
# <Axes: >

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Correlation with "depression"
correlation_series = correlations.sort_values(ascending=False)

# Plot heatmap
sns.heatmap(correlation_series.to_frame(), annot=True, cmap="coolwarm", cbar=True, fmt=".2f")
plt.title("Correlation of Columns with Depression")
plt.show()

# %%
column_drop = ["id",'City','Name','Degree','Satisfaction','Gender','Sleep Duration','Family History of Mental Illness','CGPA','Dietary Habits','Work/Study Hours','Profession']

# %%
from sklearn.preprocessing import LabelEncoder

# Initialize a label encoder
label_encoder = LabelEncoder()

# Copy the dataframe to avoid modifying the original
test_encoded = test_dup.copy()

# Encode categorical columns
categorical_columns = test_dup.select_dtypes(include=["object", "category"]).columns
for col in categorical_columns:
    test_encoded[col] = label_encoder.fit_transform(test_dup[col])

# Combine numerical and encoded categorical columns
all_columns = list(test_encoded.columns)

# Calculate correlations with "depression"
# correlations = test_encoded[all_columns].corrwith(test_encoded["Depression"])
# print(correlations)

# %%
test_encoded
# Out:
#            id  Name  Gender   Age  City  Working Professional or Student  \
# 0      140700   288       1  53.0    67                                1
# 1      140701   279       0  58.0    25                                1
# 2      140702   365       1  53.0    21                                1
# 3      140703   191       0  23.0    47                                0
# 4      140704   285       1  47.0    22                                1
# ...       ...   ...     ...   ...   ...                              ...
# 93795  234495   372       0  49.0    21                                1
# 93796  234496   292       1  29.0     3                                1
# 93797  234497   252       1  24.0    67                                0
# 93798  234498   102       0  23.0    22                                1
# 93799  234499   107       0  43.0    62                                1
#
#        Profession  CGPA  Sleep Duration  Dietary Habits  Degree  \
# ...

# %%
train_encoded = train_encoded.drop(columns=column_drop)
train_encoded
# Out:
#          Age  Working Professional or Student  \
# 0       49.0                                1
# 1       26.0                                1
# 2       33.0                                0
# 3       22.0                                1
# 4       30.0                                1
# ...      ...                              ...
# 140695  18.0                                1
# 140696  41.0                                1
# 140697  24.0                                1
# 140698  49.0                                1
# 140699  27.0                                0
#
#         Have you ever had suicidal thoughts ?  Financial Stress  Pressure  \
# 0                                           0               2.0       5.0
# 1                                           1               3.0       4.0
# 2                                           1               1.0       5.0
# 3                                           1               1.0       5.0
# ...

# %%
test_encoded = test_encoded.drop(columns=column_drop)
test_encoded
# Out:
#         Age  Working Professional or Student  \
# 0      53.0                                1
# 1      58.0                                1
# 2      53.0                                1
# 3      23.0                                0
# 4      47.0                                1
# ...     ...                              ...
# 93795  49.0                                1
# 93796  29.0                                1
# 93797  24.0                                0
# 93798  23.0                                1
# 93799  43.0                                1
#
#        Have you ever had suicidal thoughts ?  Financial Stress  Pressure
# 0                                          0               3.0       2.0
# 1                                          0               4.0       2.0
# 2                                          1               4.0       4.0
# 3                                          1               4.0       5.0
# ...

# %%
train_encoded.isnull().sum()
# Out:
# Age                                       0
# Working Professional or Student           0
# Have you ever had suicidal thoughts ?     0
# Financial Stress                          4
# Pressure                                 21
# Depression                                0
# dtype: int64

# %%
train_encoded.describe()
# Out:
#                  Age  Working Professional or Student  \
# count  140700.000000                    140700.000000
# mean       40.388621                         0.801699
# std        12.384099                         0.398722
# min        18.000000                         0.000000
# 25%        29.000000                         1.000000
# 50%        42.000000                         1.000000
# 75%        51.000000                         1.000000
# max        60.000000                         1.000000
#
#        Have you ever had suicidal thoughts ?  Financial Stress       Pressure  \
# count                          140700.000000     140696.000000  140679.000000
# mean                                0.494399          2.988983       3.027410
# std                                 0.499970          1.413633       1.401947
# min                                 0.000000          1.000000       1.000000
# 25%                                 0.000000          2.000000       2.000000
# ...

# %%
test_encoded.isnull().sum()
# Out:
# Age                                       0
# Working Professional or Student           0
# Have you ever had suicidal thoughts ?     0
# Financial Stress                          0
# Pressure                                 12
# dtype: int64

# %%
zero_column = ['Financial Stress','Pressure']
train_encoded[zero_column] = train_encoded[zero_column].fillna(0)

# %%
train_encoded.isnull().sum()
# Out:
# Age                                      0
# Working Professional or Student          0
# Have you ever had suicidal thoughts ?    0
# Financial Stress                         0
# Pressure                                 0
# Depression                               0
# dtype: int64

# %%
zero_column = ['Financial Stress','Pressure']
test_encoded[zero_column] = test_encoded[zero_column].fillna(0)

# %%
test_encoded.isnull().sum()
# Out:
# Age                                      0
# Working Professional or Student          0
# Have you ever had suicidal thoughts ?    0
# Financial Stress                         0
# Pressure                                 0
# dtype: int64

# %%
train_encoded.columns
# Out:
# Index(['Age', 'Working Professional or Student',
#        'Have you ever had suicidal thoughts ?', 'Financial Stress', 'Pressure',
#        'Depression'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,classification_report
X = train_encoded.copy()
y = X.pop('Depression')
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=0)
model = LogisticRegression()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy",accuracy_score(y_test,y_pred))
print("Classification Report",classification_report(y_test,y_pred))
# Out:
# Accuracy 0.9278962331201137
# Classification Report               precision    recall  f1-score   support
#
#            0       0.95      0.96      0.96     23099
#            1       0.81      0.77      0.79      5041
#
#     accuracy                           0.93     28140
#    macro avg       0.88      0.87      0.88     28140
# weighted avg       0.93      0.93      0.93     28140

# %%
from sklearn.tree import DecisionTreeClassifier

model_1 = DecisionTreeClassifier(random_state=0)
model_1.fit(X_train,y_train)
y_pred = model_1.predict(X_test)
print("Accuracy",accuracy_score(y_test,y_pred))
print("Classification Report",classification_report(y_test,y_pred))
# Out:
# Accuracy 0.9277896233120114
# Classification Report               precision    recall  f1-score   support
#
#            0       0.95      0.96      0.96     23099
#            1       0.82      0.77      0.79      5041
#
#     accuracy                           0.93     28140
#    macro avg       0.88      0.87      0.87     28140
# weighted avg       0.93      0.93      0.93     28140

# %%
from sklearn.ensemble import RandomForestClassifier

model_2 = RandomForestClassifier(class_weight='balanced', random_state=42)
model_2.fit(X_train, y_train)
y_pred = model_2.predict(X_test)
print("Accuracy", accuracy_score(y_test,y_pred))
print("Classification_Report", classification_report(y_test,y_pred))
# Out:
# Accuracy 0.9027718550106609
# Classification_Report               precision    recall  f1-score   support
#
#            0       0.98      0.90      0.94     23099
#            1       0.67      0.90      0.77      5041
#
#     accuracy                           0.90     28140
#    macro avg       0.82      0.90      0.85     28140
# weighted avg       0.92      0.90      0.91     28140

# %%
from xgboost import XGBClassifier

# Initialize XGBoost model
model_4 = XGBClassifier(use_label_encoder=False, eval_metric='logloss', random_state=0)

# Train the model
model_4.fit(X_train, y_train)

# Make predictions
y_pred = model_4.predict(X_test)

# Evaluate the model
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.9285358919687278
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.96      0.96     23099
#            1       0.81      0.78      0.80      5041
#
#     accuracy                           0.93     28140
#    macro avg       0.88      0.87      0.88     28140
# weighted avg       0.93      0.93      0.93     28140
